# %%
from bs4 import BeautifulSoup
from tqdm.notebook import tqdm
import concurrent.futures
import pandas as pd
import re
import requests


def get_soup(url):
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'
    }
    r = requests.get(url, headers=headers)
    soup = BeautifulSoup(r.content, 'html.parser')
    return soup

# %%
def get_seasons(url):
    soup = get_soup(url)
    
    seasons = soup.find('select', {'name': 'saison_id'}).find_all('option')
    
    ssn_list = []
    for season in seasons:
        season_id = season['value'].strip()
        season_name = season.text.strip()
        ssn_list.append({
            'season': season_name,
            'season_id': season_id
        })
    return ssn_list

club_url = 'https://www.transfermarkt.us/tranmere-rovers/kader/verein/1074/saison_id/2024/'

seasons = get_seasons(club_url)

seasons[:3]
# Out:
# [{'season': '24/25', 'season_id': '2024'},
#  {'season': '23/24', 'season_id': '2023'},
#  {'season': '22/23', 'season_id': '2022'}]

# %%
def get_ssn_url(season_id):
    return f'https://www.transfermarkt.us/tranmere-rovers/kader/verein/1074/saison_id/{season_id}'

# %%
def get_players(soup):
    return soup.find_all(class_='posrela')

def get_player_link(player):
    p = player.find(class_='hauptlink').find('a')
    player_name = p.text.strip()
    player_url = p['href']
    return {
        'player_name': player_name,
        'player_url': player_url
    }

# %% [markdown]
# # Get player names and URLs for every season

# %%
def process_season(season):
    season_id = season['season_id']
    season_url = get_ssn_url(season_id)
    soup = get_soup(season_url)
    players = get_players(soup)
    
    player_links = []
    for player in players:
        player_link = get_player_link(player)
        player_links.append(player_link)
    return player_links

plr_list = []

with concurrent.futures.ThreadPoolExecutor() as executor:
    futures = [executor.submit(process_season, s) for s in seasons]
    
    for future in tqdm(concurrent.futures.as_completed(futures)):
        plr_list.extend(future.result())
# Out:
# 0it [00:00, ?it/s]

# %%
plr_list = pd.DataFrame(plr_list).drop_duplicates().to_dict(orient='records')

plr_list[:3]
# Out:
# [{'player_name': 'Iain Turner',
#   'player_url': '/iain-turner/profil/spieler/3582'},
#  {'player_name': 'Scott Davies',
#   'player_url': '/scott-davies/profil/spieler/67273'},
#  {'player_name': 'Paddy Wharton',
#   'player_url': '/paddy-wharton/profil/spieler/504952'}]

# %% [markdown]
# # Get HTML content of player profile

# %%
def process_player(plr):
    plr_url = f"https://www.transfermarkt.us{plr['player_url']}"
    plr_name = plr['player_name']
    plr_soup = get_soup(plr_url)
    return {
        'player_name': plr_name,
        'player_url': plr_url,
        'player_html': plr_soup
    }

plrs_html = []

with concurrent.futures.ThreadPoolExecutor() as executor:
    futures = [executor.submit(process_player, plr) for plr in plr_list]
    
    for future in tqdm(concurrent.futures.as_completed(futures)):
        plrs_html.append(future.result())
# Out:
# 0it [00:00, ?it/s]

# %% [markdown]
# # Pull player positions from player html

# %%
df = pd.DataFrame(plrs_html)

def get_position(soup):
    positions = soup.find_all('dd', class_='detail-position__position')
    return [pos.text.strip() for pos in positions]

df['positions'] = df['player_html'].apply(get_position)

df['positions'][:3]
# Out:
# 0                         [Goalkeeper]
# 1                        [Centre-Back]
# 2    [Centre-Back, Defensive Midfield]
# Name: positions, dtype: object

# %% [markdown]
# # Fix names pulled from Transfermarkt to match names in main dataset

# %%
name_fixes = {
    'Ken Beamish': 'Kenny Beamish',
    'Dave Burgess': 'David Burgess',
    'Jim Cassidy': 'James Cassidy',
    'James Cumbes': 'Jim Cumbes',
    'Ron Dellow': 'Ronnie Dellow',
    'Stanley Docking': 'Stan Docking',
    'Herbert Hamilton': 'Duke Hamilton',
    'Jim Harvey': 'Jimmy Harvey',
    'Steve Jennings': 'Steven Jennings',
    'Ousmane Kane': 'Ousmane Kané',
    'Matty Kennedy': 'Matthew Kennedy',
    'John King': 'Johnny King',
    'Nathaniel Knight-Percival': 'Nat Knight-Percival',
    'Shay Logan': 'Shaleum Logan',
    'Jonathon Margetts': 'Johnny Margetts',
    'Hugh McAuley': 'Hughie McAuley',
    'Jay McEveley': 'James McEveley',
    'Manny Monthe': 'Emmanuel Monthe',
    'John Morrissey': 'Johnny Morrissey',
    'Joe Starbuck': 'Joseph Starbuck',
    'James Steel': 'Jim Steel',
    "Steven O'Leary": "Stephen O'Leary",
    'Sam Taylor': 'Samuel Taylor',
    'Danny Woodards': 'Dan Woodards',
}

for name in name_fixes:
    df.loc[df['player_name'] == name, 'player_name'] = name_fixes[name]

# %% [markdown]
# # Add player positions to dataframe

# %%
# Find the maximum length of the lists in 'positions' column
max_len = df['positions'].apply(len).max()

# Create new columns 'position_1', 'position_2', etc.
for i in range(max_len):
    df[f'tm_pos_{i+1}'] = df['positions'].apply(lambda x: x[i] if i < len(x) else None)

# Drop the original 'positions' column
df = df.drop(columns=['positions'])

# %% [markdown]
# # Pull players' birth dates from Transfermarky HTML

# %%
def get_dob(soup):
    soup = str(soup)
    pattern = r'\d{4}-\d{2}-\d{2}'
    match = re.search(pattern, soup)
    if match:
        return match.group()
    else:
        return None
    
df['dob'] = df['player_html'].apply(get_dob)

# %% [markdown]
# # Fix incorrect dates of birth found in Transfermarkt data

# %%
dob_fixes = {
    'Ernie Davies': '1916-01-31',
    'Kane Hemmings': '1991-04-08',
    'Rob Apter': '2003-04-23',
    'Ryan Edwards': '1993-10-07',
    'Scott Davies': '1987-02-23',
    "Stephen O'Leary": '1987-02-02',
    'Will Aimson': '1994-06-03',
}

for name in dob_fixes:
    df.loc[df.player_name==name, 'dob'] = dob_fixes[name]

# %%
pos_df = df.drop(columns=['player_url', 'player_html']).copy()

# %%
pos_df
# Out:
#              player_name          tm_pos_1            tm_pos_2  \
# 0          Paddy Wharton        Goalkeeper                None
# 1             Evan Gumbs       Centre-Back                None
# 2        Declan Drysdale       Centre-Back  Defensive Midfield
# 3        Michael Ihiekwe       Centre-Back          Right-Back
# 4            Iain Turner        Goalkeeper                None
# ..                   ...               ...                 ...
# 582           Mark Duffy  Central Midfield  Attacking Midfield
# 583       John Griffiths              None                None
# 584          Josh McPake    Right Midfield        Right Winger
# 585     Callum McManaman      Right Winger         Left Winger
# 586  Emmanuel Dieseruvwe    Centre-Forward                None
#
#            tm_pos_3         dob
# 0              None  2000-05-27
# 1              None  1997-07-21
# 2              None  1999-11-14
# 3              None  1992-11-20
# 4              None  1984-01-26
# ..              ...         ...
# 582  Right Midfield  1985-10-07
# 583            None        None
# 584     Left Winger  2001-08-31
# 585  Second Striker  1991-04-25
# 586            None  1995-02-20
#
# [587 rows x 5 columns]

# %% [markdown]
# # Split names to create forename and surname columns

# %%
def split_name(name):
    if name == 'Pedro Miguel Matias':
        forename = 'Pedro Miguel'
        surname = 'Matias'
    else:
        parts = name.split()
        forename = parts[0]
        surname = ' '.join(parts[1:])
    return pd.Series([forename, surname])
    
pos_df[['forename', 'surname']] = pos_df['player_name'].apply(split_name)

pos_df = pos_df.sort_values(['surname', 'forename', 'dob'])

# %% [markdown]
# # Fix errors in Transfermarkt player positions

# %%
pos_fixes = {
    'Lucas Akins': ['Right Winger', 'Centre-Forward'],
    'Graham Allen': ['Centre-Back', 'Right-Back'],
    'Doug Anderson': ['Winger'],
    'John Aspinall': ['Winger'],
    'Michael Black': ['Left Winger', 'Right Winger'],
    'Paul Black': ['Left-Back', None],
    'Ivano Bonetti': ['Right Winger', 'Left Winger'],
    'Ged Brannan': ['Central Midfield', 'Left-Back'],
    'Paul Brown': ['Left Midfield'],
    'Shane Cansdell-Sherriff': ['Left-Back', 'Centre-Back'],
    'Logan Chalmers': ['Left Winger', 'Right Winger', None],
    'Paul Cook': ['Central Midfield', 'Left Midfield'],
    'Tom Curtis': ['Central Midfield'],
    'Janoi Donacien': ['Centre-Back', 'Right-Back', None],
    'Sean Flynn': ['Central Midfield'],
    'Stephen Frail': ['Right-Back', 'Defensive Midfield'],
    'Wayne Gill': ['Attacking Midfielder'],
    'Jermaine Grandison': ['Centre-Back'],
    'Jimmy Harvey': ['Central Midfield'],
    'Alex Hay': ['Centre-Forward', 'Right Winger'],
    'Dave Higgins': ['Centre-Back'],
    'Matt Hill': ['Left-Back', None],
    'Mark Hughes': ['Centre-Back', 'Sweeper'],
    'Gary Jones': ['Central Midfield', 'Striker', 'Centre-Back'],
    'Dave Martindale': ['Central Midfield', 'Defensive Midfield'],
    'Pedro Miguel Matias': ['Left Winger'],
    'Micky Mellon': ['Central Midfield'],
    "Seyni N'Diaye": ['Center-Forward'],
    'James Olsen': ['Left-Back', 'Left Midfield'],
    'Elliot Osborne': ['Central Midfield'],
    'Andy Thompson': ['Left-Back'],
    'Ryan Williams': ['Attacking Midfielder'],
    'Steve Yates': ['Centre-Back', 'Right-Back', 'Left-Back']
}

for player, positions in pos_fixes.items():
    for i, pos in enumerate(positions):
        pos_df.loc[pos_df.player_name==player, f'tm_pos_{i+1}'] = pos

pos_df = pos_df[['surname', 'forename',  'player_name', 'dob', 'tm_pos_1', 'tm_pos_2', 'tm_pos_3']]

pos_df.head(5)
# Out:
#         surname forename      player_name         dob          tm_pos_1  \
# 262  Achterberg     John  John Achterberg  1971-07-08        Goalkeeper
# 486      Adkins    Nigel     Nigel Adkins  1965-03-11        Goalkeeper
# 277       Ahmed    Adnan      Adnan Ahmed  1984-06-07  Central Midfield
# 193      Aimson     Will      Will Aimson  1994-06-03       Centre-Back
# 404      Aiston      Sam       Sam Aiston  1976-11-21     Left Midfield
#
#     tm_pos_2 tm_pos_3
# 262     None     None
# 486     None     None
# 277     None     None
# 193     None     None
# 404     None     None

# %%
import re

def view_special_chars(df, col):
    pattern = re.compile(r'[^\x00-\x7F]+')
    return df[df[col].str.contains(pattern)]

view_special_chars(pos_df, 'player_name')
# Out:
#           surname   forename         player_name         dob  \
# 311        Carole  Sébastien    Sébastien Carole  1982-09-08
# 368          Dadi     Eugène         Eugène Dadi  1973-08-20
# 131  Fôn Williams      Owain  Owain Fôn Williams  1987-03-17
# 325      Golobart      Román      Román Golobart  1992-03-21
# 223       Gulácsi      Péter       Péter Gulácsi  1990-05-06
# 436          Kané    Ousmane        Ousmane Kané  2001-07-23
# 380        Sidibé     Mamady       Mamady Sidibé  1979-12-18
# 25          Sousa      Érico         Érico Sousa  1995-03-12
# 88         Traoré     Drissa       Drissa Traoré  1992-03-25
#
#                tm_pos_1            tm_pos_2        tm_pos_3
# 311        Right Winger  Attacking Midfield  Right Midfield
# 368      Centre-Forward                None            None
# 131          Goalkeeper                None            None
# 325         Centre-Back                None            None
# 223          Goalkeeper                None            None
# 436  Defensive Midfield    Central Midfield            None
# 380      Centre-Forward                None            None
# 25          Left Winger        Right Winger            None
# 88     Central Midfield  Defensive Midfield            None

# %%
def replace_special_chars(name):
    name = name.replace('á', 'a')
    name = name.replace('é', 'e')
    name = name.replace('é', 'e')
    name = name.replace('è', 'e')
    name = name.replace('É', 'E')
    name = name.replace('ô', 'o')
    return name

view_special_chars(pos_df, 'player_name')
# Out:
#           surname   forename         player_name         dob  \
# 311        Carole  Sébastien    Sébastien Carole  1982-09-08
# 368          Dadi     Eugène         Eugène Dadi  1973-08-20
# 131  Fôn Williams      Owain  Owain Fôn Williams  1987-03-17
# 325      Golobart      Román      Román Golobart  1992-03-21
# 223       Gulácsi      Péter       Péter Gulácsi  1990-05-06
# 436          Kané    Ousmane        Ousmane Kané  2001-07-23
# 380        Sidibé     Mamady       Mamady Sidibé  1979-12-18
# 25          Sousa      Érico         Érico Sousa  1995-03-12
# 88         Traoré     Drissa       Drissa Traoré  1992-03-25
#
#                tm_pos_1            tm_pos_2        tm_pos_3
# 311        Right Winger  Attacking Midfield  Right Midfield
# 368      Centre-Forward                None            None
# 131          Goalkeeper                None            None
# 325         Centre-Back                None            None
# 223          Goalkeeper                None            None
# 436  Defensive Midfield    Central Midfield            None
# 380      Centre-Forward                None            None
# 25          Left Winger        Right Winger            None
# 88     Central Midfield  Defensive Midfield            None

# %% [markdown]
# # Create `player_id` column

# %%
def create_player_id(row):
    forename = row['forename']
    forename = replace_special_chars(forename)
    surname = row['surname']
    surname = replace_special_chars(surname)
    dob = row['dob']
    player_id = f'{surname}{forename}{dob}'.replace('.0', '').replace('-', '').replace("'", '').replace(' ', '')
    return player_id

pos_df['player_id'] = pos_df.apply(create_player_id, axis=1)

pos_df
# Out:
#         surname forename      player_name         dob          tm_pos_1  \
# 262  Achterberg     John  John Achterberg  1971-07-08        Goalkeeper
# 486      Adkins    Nigel     Nigel Adkins  1965-03-11        Goalkeeper
# 277       Ahmed    Adnan      Adnan Ahmed  1984-06-07  Central Midfield
# 193      Aimson     Will      Will Aimson  1994-06-03       Centre-Back
# 404      Aiston      Sam       Sam Aiston  1976-11-21     Left Midfield
# ..          ...      ...              ...         ...               ...
# 402       Yates    Steve      Steve Yates  1970-01-29       Centre-Back
# 509       Yeats      Ron        Ron Yeats  1937-11-15       Centre-Back
# 65        Young     Jack       Jack Young  2000-10-21  Central Midfield
# 512       Young    Tommy      Tommy Young  1947-12-24    Centre-Forward
# 320        Zola   Calvin      Calvin Zola  1984-12-31    Centre-Forward
#
#                tm_pos_2   tm_pos_3               player_id
# 262                None       None  AchterbergJohn19710708
# 486                None       None     AdkinsNigel19650311
# 277                None       None      AhmedAdnan19840607
# 193                None       None      AimsonWill19940603
# 404                None       None       AistonSam19761121
# ..                  ...        ...                     ...
# 402          Right-Back  Left-Back      YatesSteve19700129
# 509                None       None        YeatsRon19371115
# 65   Defensive Midfield       None       YoungJack20001021
# 512  Attacking Midfield       None      YoungTommy19471224
# 320                None       None      ZolaCalvin19841231
#
# [587 rows x 8 columns]

# %%
r_ids = pd.read_csv('~/Desktop/player_ids.csv')[['player_name', 'player_id', 'player_dob']].drop_duplicates().reset_index(drop=True)

for name in dob_fixes:
    df.loc[df.player_name==name, 'dob'] = dob_fixes[name]

r_ids
# Out:
#           player_name               player_id  player_dob
# 0        Alan A'Court      ACourtAlan19340930  1934-09-30
# 1     John Achterberg  AchterbergJohn19710708  1971-07-08
# 2        Arthur Adams             AdamsArthur         NaN
# 3        Edward Adams     AdamsEdward19081112  1908-11-12
# 4        Nigel Adkins     AdkinsNigel19650311  1965-03-11
# ...               ...                     ...         ...
# 1020       Wilf Yates           YatesWilf1898         NaN
# 1021        Ron Yeats        YeatsRon19371115  1937-11-15
# 1022       Jack Young       YoungJack20001021  2000-10-21
# 1023      Tommy Young      YoungTommy19471224  1947-12-24
# 1024      Calvin Zola      ZolaCalvin19841231  1984-12-31
#
# [1025 rows x 3 columns]

# %%
errors = pos_df[~pos_df.player_id.isin(r_ids.player_id)][['player_name', 'player_id']]

errors
# Out:
#        player_name             player_id
# 43    Udoyen Akpan   AkpanUdoyen19990210
# 464  John Aldridge  AldridgeJohn19590918
# 11    Darren Askew       AskewDarrenNone
# 326      Tom Baker      BakerTom19850328
# 455   Gary Bennett   BennettGary19630920
# ..             ...                   ...
# 495    Gordon West    WestGordon19430324
# 147  Jack Williams  WilliamsJack20030516
# 479  John Williams  WilliamsJohn19611003
# 376  Josh Williams  WilliamsJosh20040713
# 256  Alex Woodyard  WoodyardAlex19921116
#
# [75 rows x 2 columns]

# %%
errors = pd.read_csv('~/Desktop/error_actions.csv')

errors = errors[~errors.player_id.isin(r_ids.player_id)]

errors
# Out:
#          player_name                player_id     action
# 3       Ernie Davies      DaviesErnie19160131        dob
# 5       Oliver James      JamesOliver19870130  check dob
# 6        Ethan Jones       JonesEthan20041016  check dob
# 7         Gwyn Jones        JonesGwyn19120221        dob
# 8        Jack Kearns       KearnsJack19140104        dob
# 10  Clayton McDonald  McDonaldClayton19881206  check dob
# 11      Arnaud Mendy      MendyArnaud19900210  check dob
# 12      Ronnie Moore      MooreRonnie19530429  check dob
# 13     Seyni N'Diaye      NDiayeSeyni19730906  check dob
# 14     James Norwood     NorwoodJames19900905  check dob
# 15   Stephen O'Leary    OLearyStephen19850202        dob
# 16    Elliot Osborne    OsborneElliot19960516  check dob
# 17      Ryan Shotton      ShottonRyan19880930  check dob
# 18        Akpo Sodje        SodjeAkpo19800131  check dob
# 19     Ben Tomlinson     TomlinsonBen19891031  check dob
# 21     Alex Woodyard     WoodyardAlex19921116  check dob

# %%
# Transfermarkt DOBs that need to be fixed
tm_dob_fix_names = ['Clayton McDonald', 'Ronnie Moore', 'Seyni N\'Diaye', 'James Norwood']

tm_dob_fixes = r_ids[r_ids.player_name.isin(tm_dob_fix_names)].to_dict(orient='records')

for fix in tm_dob_fixes:
    pos_df.loc[pos_df.player_name==fix['player_name'], 'dob'] = fix['player_dob']

# %%
remove = pos_df[~pos_df.player_name.apply(replace_special_chars).isin(r_ids.player_name.apply(replace_special_chars))]

remove
# Out:
#          surname  forename        player_name         dob            tm_pos_1  \
# 43         Akpan    Udoyen       Udoyen Akpan  1999-02-10      Centre-Forward
# 11         Askew    Darren       Darren Askew        None                None
# 326        Baker       Tom          Tom Baker  1985-03-28    Central Midfield
# 227       Benson      Liam        Liam Benson  1992-02-25           Left-Back
# 160       Boland   Antonie     Antonie Boland  1994-12-30         Centre-Back
# 132     Courtney      John      John Courtney  1994-01-12          Goalkeeper
# 23      Croughan       Tom       Tom Croughan  1999-09-19      Second Striker
# 481       Currie      Tony        Tony Currie  1950-01-01  Attacking Midfield
# 44        Davies      Liam        Liam Davies  1996-07-02       Left Midfield
# 452        Davis      Neil         Neil Davis  1973-08-15                None
# 382      Davison      Josh       Josh Davison  1999-09-16      Centre-Forward
# 15        Devine       Jay         Jay Devine  1999-07-26    Central Midfield
# 573        Dwyer     Dylan        Dylan Dwyer  2003-09-06           Left-Back
# 373       Finley       Sam         Sam Finley  1992-08-04    Central Midfield
# 128       Fisher       Max         Max Fisher  2003-10-03      Centre-Forward
# 10       Fleming      Jack       Jack Fleming  1999-01-10         Centre-Back
# 93   Gouldbourne     Ethan  Ethan Gouldbourne  2000-11-10    Central Midfield
# 583    Griffiths      John     John Griffiths        None                None
# 298     Johnston   Michael   Michael Johnston  1987-12-16         Centre-Back
# 72         Jones       Ben          Ben Jones  2000-11-29          Goalkeeper
# 264      Kennedy     Peter      Peter Kennedy        None          Goalkeeper
# 447        Lacey      Luis         Luis Lacey  2005-01-09           Left-Back
# 85          Long      Nick          Nick Long  2001-01-10         Centre-Back
# 173        Maher       Ben          Ben Maher  1995-09-28    Central Midfield
# 351      McGuire     Jamie      Jamie McGuire  1983-11-13    Central Midfield
# 289     McWeeney     Shane     Shane McWeeney  1989-10-14          Goalkeeper
# 224       Miotto     Simon       Simon Miotto  1969-09-05          Goalkeeper
# 414        Moran      Andy         Andy Moran  1979-10-07      Centre-Forward
# 176       Morris    Callum      Callum Morris  1992-09-01    Central Midfield
# 251     Musuamba  Harrison  Harrison Musuamba  2002-05-20                None
# 375       Norman   Cameron     Cameron Norman  1995-10-12          Right-Back
# 324   Palethorpe      Phil    Phil Palethorpe  1986-09-17          Goalkeeper
# 247      Passant  Bayleigh   Bayleigh Passant  2000-11-29          Goalkeeper
# 413        Ralph    Andrew       Andrew Ralph  1983-05-28          Goalkeeper
# 465        Ralph      Andy         Andy Ralph  1983-05-28          Goalkeeper
# 122   Ramsbottom       Sam     Sam Ramsbottom  1996-04-03          Goalkeeper
# 421       Robson     Conor       Conor Robson  2003-09-21          Goalkeeper
# 377      Solomon       Sol        Sol Solomon  2001-03-17      Centre-Forward
# 260     Thompson    Bailey    Bailey Thompson  2001-06-07      Centre-Forward
# 91        Timlin     Jamie       Jamie Timlin  2003-09-16      Centre-Forward
# 511        Tynan     Tommy        Tommy Tynan  1955-11-17      Centre-Forward
# 322       Vaulks      Will        Will Vaulks  1993-09-13  Defensive Midfield
# 155      Watkins   Bradley    Bradley Watkins  1994-09-11          Goalkeeper
# 147     Williams      Jack      Jack Williams  2003-05-16        Right Winger
# 376     Williams      Josh      Josh Williams  2004-07-13    Central Midfield
#
#                tm_pos_2            tm_pos_3                 player_id
# 43       Second Striker        Right Winger       AkpanUdoyen19990210
# 11                 None                None           AskewDarrenNone
# 326                None                None          BakerTom19850328
# 227         Centre-Back          Right-Back        BensonLiam19920225
# 160           Left-Back  Defensive Midfield     BolandAntonie19941230
# 132                None                None      CourtneyJohn19940112
# 23   Attacking Midfield    Central Midfield       CroughanTom19990919
# 481                None                None        CurrieTony19500101
# 44          Left Winger      Right Midfield        DaviesLiam19960702
# 452                None                None         DavisNeil19730815
# 382                None                None       DavisonJosh19990916
# 15   Defensive Midfield                None         DevineJay19990726
# 573                None                None        DwyerDylan20030906
# 373      Right Midfield  Attacking Midfield         FinleySam19920804
# 128                None                None         FisherMax20031003
# 10            Left-Back                None       FlemingJack19990110
# 93                 None                None  GouldbourneEthan20001110
# 583                None                None         GriffithsJohnNone
# 298           Left-Back          Right-Back   JohnstonMichael19871216
# 72                 None                None          JonesBen20001129
# 264                None                None          KennedyPeterNone
# 447         Left Winger    Central Midfield         LaceyLuis20050109
# 85                 None                None          LongNick20010110
# 173      Centre-Forward          Right-Back          MaherBen19950928
# 351  Defensive Midfield                None      McGuireJamie19831113
# 289                None                None     McWeeneyShane19891014
# 224                None                None       MiottoSimon19690905
# 414                None                None         MoranAndy19791007
# 176      Right Midfield  Attacking Midfield      MorrisCallum19920901
# 251                None                None  MusuambaHarrison20020520
# 375         Centre-Back           Left-Back     NormanCameron19951012
# 324                None                None    PalethorpePhil19860917
# 247                None                None   PassantBayleigh20001129
# 413                None                None       RalphAndrew19830528
# 465                None                None         RalphAndy19830528
# 122                None                None     RamsbottomSam19960403
# 421                None                None       RobsonConor20030921
# 377         Left Winger                None        SolomonSol20010317
# 260                None                None    ThompsonBailey20010607
# 91                 None                None       TimlinJamie20030916
# 511        Right Winger                None        TynanTommy19551117
# 322         Centre-Back          Right-Back        VaulksWill19930913
# 155                None                None    WatkinsBradley19940911
# 147  Attacking Midfield         Left Winger      WilliamsJack20030516
# 376  Attacking Midfield                None      WilliamsJosh20040713
